# %%
def merge(arr,l,m,h):
  i=l
  k=l
  j=m+1
  Sorted = []


  while (j<=h)and (i<=m):
    if arr[i]< arr[j]:
      Sorted.append(arr[i])
      i=i+1
    else:
      Sorted.append(arr[j])
      j=j+1 
  if i > m:
    while j <= h:
      Sorted.append(arr[j])
      j=j+1
  else:
    while i <=m:
      Sorted.append(arr[i])
      i=i+1
  p=0
  for i in range(l,h+1):
    arr[i]=Sorted[p]
    p=p+1
    

  return Sorted



def mergeSort(array,low,high):

  if low<high:
    
    mid = int((low+high)/2)
    mergeSort(array,low,mid)
    mergeSort(array,mid+1,high)
    
    sorted = merge(array,low,mid,high)
    

      




array=[5,0,24,8,10,3,16,10,-20]
mergeSort(array,0,len(array)-1)
print(array)
# Out:
# [-20, 0, 3, 5, 8, 10, 10, 16, 24]
