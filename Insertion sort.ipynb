# %%
array = [10,11,1,5,2,3]

for x in range(1,len(array)):
  temp=array[x]
  for y in range(x-1,-1,-1): 
    if  array[y] > temp:
      array[y+1]=array[y]
      array[y]=temp
      print("array " , array)  

    else:    
      break  
  
      
 
print(array)
# Out:
# array  [10, 1, 11, 5, 2, 3]
# array  [1, 10, 11, 5, 2, 3]
# array  [1, 10, 5, 11, 2, 3]
# array  [1, 5, 10, 11, 2, 3]
# array  [1, 5, 10, 2, 11, 3]
# array  [1, 5, 2, 10, 11, 3]
# array  [1, 2, 5, 10, 11, 3]
# array  [1, 2, 5, 10, 3, 11]
# array  [1, 2, 5, 3, 10, 11]
# array  [1, 2, 3, 5, 10, 11]
# [1, 2, 3, 5, 10, 11]
