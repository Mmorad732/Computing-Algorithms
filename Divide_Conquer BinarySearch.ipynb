# %%
def binarySearch(a,low,high,n):
  flag = False
  if low <= high:
    m = int((low+high)/2)
    if a[m] == n:
      print("True")
    elif n < a[m]:
      binarySearch(a,low,m-1,n)
    elif n > a[m]:
      binarySearch(a,m+1,high,n)
  else:
    print(Flag) 
      





def main():
  array = [1,2,3,5,8,10,15,20,26]
  binarySearch(array,0,len(array)-1,26)

if __name__ == "__main__":
  main()
# Out:
# True
