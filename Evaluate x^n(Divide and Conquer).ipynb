# %%
def evaluate(n,x):
  if x == 0:
    return 1
  elif x%2 == 0:
    return evaluate(n,x/2)*evaluate(n,x/2)
  elif x == 1:
    return n
  else:
    return evaluate(n,x-1)*evaluate(n,1)
def power(n,x):
  if x== 0:
    return 1
  if x%2 == 0:
    return power(n,x/2)*power(n,x/2) 
  else:
    return n * power(n,x-1)#*power(n,x-1/2) 


n = int(input("Enter number "))
x = int(input("Enter power "))
print("Answer = ",evaluate(n,x))
# Out:
# Enter number 2
# Enter power 8
# Answer =  256
